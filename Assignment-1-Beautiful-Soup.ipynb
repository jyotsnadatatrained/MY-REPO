# %% [markdown]
#   # ASSIGNMENT-1
# # WEB SCRAPING BeautifulSoup

# %%
# Install all required libraries
# !pip install bs4
# !pip install requests
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=8b10707d14263c077a99f8747bf51b20e88403d5d29a495939f42fdaef296458
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %%
# importing the required libraries
from bs4 import BeautifulSoup,SoupStrainer
import requests
import pandas as pd

# %% [markdown]
# # 1) Write a python program to display all the header tags from wikipedia.org.

# %%
#Send get request to the webpage server to get the source code of the page
url='https://en.wikipedia.org/wiki/Main_Page'
page = requests.get(url)
# page content
soup = BeautifulSoup(page.content)
# Scrap the Header tag
header_tags=[]

for header in soup.find_all(["h1","h2","h3","h4","h5","h6"]):
    header_tags.append(header.name+" "+header.text.strip())

#print all header_tags
header_tags
# Out:
# ['h1 Main Page',
#  'h1 Welcome to Wikipedia',
#  "h2 From today's featured article",
#  'h2 Did you know\xa0...',
#  'h2 In the news',
#  'h2 On this day',
#  "h2 From today's featured list",
#  "h2 Today's featured picture",
#  'h2 Other areas of Wikipedia',
#  "h2 Wikipedia's sister projects",
#  'h2 Wikipedia languages']

# %% [markdown]
# # 2) Write s python program to display list of respected former presidents of India(i.e. Name , Term of office) from https://presidentofindia.nic.in/former-presidents.htm

# %%
# Send url request and download page content
presedent_soup=BeautifulSoup(requests.get("https://presidentofindia.nic.in/former-presidents.htm").content,"html.parser")
# Scrap President name
name=[i.text.split('\n')[1] for i in presedent_soup.find_all('div',class_="presidentListing")]
# Scrap terms of office
office_term=[i.text.split('\n')[2] for i in presedent_soup.find_all('div',class_="presidentListing")]
# Create DataFrame
former_President=pd.DataFrame({"Former Presidents":name,"Term of Office":office_term})
former_President
# Out:
# Empty DataFrame
# Columns: [Former Presidents, Term of Office]
# Index: []

# %% [markdown]
# # 3) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
# b) Top 10 ODI Batsmen along with the records of their team and rating.
#
# c) Top 10 ODI bowlers along with the records of their team and rating.
#
# # a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
page5 = requests.get(url)
# see content in page5
soup5 = BeautifulSoup(page5.content)
#scrape team names
team = soup5.find_all("span",class_='u-hide-phablet')
team_name = []
for i in team:
    team_name.append(i.text)
matches = [] #empty list
points = [] #empty list
ratings = [] #empty list
new_list = [] #empty list

for i in soup5.find_all("td",class_='rankings-block__banner--matches'): # first place team number of matches
    matches.append(i.text)
for i in soup5.find_all("td",class_='rankings-block__banner--points'):# first place team points
    points.append(i.text)
for i in soup5.find_all("td",class_='rankings-block__banner--rating u-text-right'):# first place team ratings
    ratings.append(i.text.replace("\n",""))
for i in soup5.find_all("td",class_='table-body__cell u-center-text'):# other teams number of matches and points
    new_list.append(i.text)
for i in range(0,len(new_list)-1,2):
    matches.append(new_list[i]) # other teams matches
    points.append(new_list[i+1]) # other teams points
for i in soup5.find_all("td",class_='table-body__cell u-text-right rating'):# other teams ratings
    ratings.append(i.text)

# Make data frame of top 10 ICC teams
icc=pd.DataFrame({})
icc['Team_name']=team_name[:10]
icc['Matches']=matches[:10]
icc['Points']=points[:10]
icc['Ratings']=ratings[:10]
icc
# Out:
#       Team_name Matches Points  \
# 0     Australia      23  2,714
# 1      Pakistan      20  2,316
# 2         India      33  3,807
# 3   New Zealand      27  2,806
# 4       England      24  2,426
# 5  South Africa      19  1,910
# 6    Bangladesh      27  2,520
# 7   Afghanistan      15  1,361
# 8     Sri Lanka      32  2,794
# 9   West Indies      35  2,312
#
#                                              Ratings
# 0                              118               ...
# 1                                                116
# 2                                                115
# 3                                                104
# 4                                                101
# 5                                                101
# 6                                                 93
# 7                                                 91
# 8                                                 87
# 9                                                 66

# %% [markdown]
# # b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
#send get request to the webpage server to get the source code of the page
batsmen_teams=BeautifulSoup(requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi').content,'html.parser')

player=[ i.text.strip() for i in batsmen_teams.find_all('td',class_='table-body__cell name')][:10] # Scrap player

team=[ i.text for i in batsmen_teams.find_all('span',class_='table-body__logo-text')][:10] # Scrap Team
rating=[i.text for i in batsmen_teams.find_all('td',class_='table-body__cell u-text-right rating')][:10] # Scrap Rating
batsmen=pd.DataFrame({'Player':player,'Team':team,'Ratings':rating})
batsmen
# Out:
#                   Player Team Ratings
# 0  Rassie van der Dussen   SA     777
# 1           Fakhar Zaman  PAK     755
# 2            Imam-ul-Haq  PAK     745
# 3           Shubman Gill  IND     743
# 4           Harry Tector  IRE     726
# 5           David Warner  AUS     726
# 6        Quinton de Kock   SA     718
# 7            Virat Kohli  IND     705
# 8            Steve Smith  AUS     702
# 9         Mitchell Starc  AUS     686

# %% [markdown]
# # c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
#send get request to the webpage server to get the source code of the page and download the page content
batsmen_teams=BeautifulSoup(requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling').content,'html.parser')

player=[ i.text.strip() for i in batsmen_teams.find_all('td',class_='table-body__cell rankings-table__name name')][:10] # player

team1=[ i.text for i in batsmen_teams.find_all('span',class_='table-body__logo-text')][:10] # team
rating2=[i.text for i in batsmen_teams.find_all('td',class_='table-body__cell rating')][:10] # rating
bowlers=pd.DataFrame({'Player':player,'Team':team1,'Ratings':rating2}) # DataFrame created
bowlers
# Out:
#              Player Team Ratings
# 0    Mitchell Starc  AUS     686
# 1       Rashid Khan  AFG     682
# 2    Mohammed Siraj  IND     670
# 3        Matt Henry   NZ     667
# 4  Mujeeb Ur Rahman  AFG     661
# 5       Trent Boult   NZ     660
# 6        Adam Zampa  AUS     652
# 7    Shaheen Afridi  PAK     630
# 8     Kuldeep Yadav  IND     622
# 9   Shakib Al Hasan  BAN     618

# %% [markdown]
# # 4) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
#
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %% [markdown]
# # a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
#send get request to the webpage server to get the source code of the page and download the page content
ODI_teams=BeautifulSoup(requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi').content,'html.parser')
team=[ i.text for i in ODI_teams.find_all('span',class_='u-hide-phablet')] # team
matches=[ i.text for i in ODI_teams.find_all('td',class_='table-body__cell u-center-text')]
matches1=[matches[i] for i in range(0,len(matches),2)][:10]  # matches
points=[matches[i] for i in range(1,len(matches),2)][:10]  # points
ratings=[ i.text for i in ODI_teams.find_all('td',class_='table-body__cell u-text-right rating')][:10] # ratings
df=pd.DataFrame({'Matches':matches1,'Points':points,'Ratings':ratings})
df
# Out:
#   Matches Points Ratings
# 0      31  3,875     125
# 1      26  3,098     119
# 2      30  3,039     101
# 3      28  2,688      96
# 4      29  2,743      95
# 5      17  1,284      76
# 6      12    820      68
# 7      13    883      68
# 8      27  1,678      62
# 9      18    660      37

# %% [markdown]
# # b) Top 10 women’s ODI Batting players along with the records of their team and rating.

# %%
#send get request to the webpage server to get the source code of the page and download the page content
batsmen_teams=BeautifulSoup(requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi').content,'html.parser')
player=[ i.text.strip() for i in batsmen_teams.find_all('td',class_='table-body__cell name')][:10] #player

team1=[ i.text for i in batsmen_teams.find_all('span',class_='table-body__logo-text')][:10] # team
rating2=[i.text for i in batsmen_teams.find_all('td',class_='table-body__cell u-text-right rating')][:10] # rating
batting=pd.DataFrame({'Player':player,'Team':team1,'Ratings':rating2})
batting
# Out:
#                 Player Team Ratings
# 0  Chamari Athapaththu   SL     758
# 1          Beth Mooney  AUS     751
# 2      Laura Wolvaardt   SA     732
# 3      Smriti Mandhana  IND     708
# 4         Alyssa Healy  AUS     702
# 5     Harmanpreet Kaur  IND     694
# 6         Ellyse Perry  AUS     686
# 7          Meg Lanning  AUS     682
# 8      Stafanie Taylor   WI     618
# 9       Shabnim Ismail   SA     722

# %% [markdown]
# # c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
#send get request to the webpage server to get the source code of the page and download the page content
batsmen_teams=BeautifulSoup(requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder').content,'html.parser')
player=[ i.text.strip() for i in batsmen_teams.find_all('td',class_='table-body__cell rankings-table__name name')][:10]  #player

team1=[ i.text for i in batsmen_teams.find_all('span',class_='table-body__logo-text')][:10] # team
rating2=[i.text for i in batsmen_teams.find_all('td',class_='table-body__cell rating')][:10] #rating
all_rounder=pd.DataFrame({'Player':player,'Team':team1,'Ratings':rating2})
all_rounder
# Out:
#               Player Team Ratings
# 0   Ashleigh Gardner  AUS     389
# 1    Hayley Matthews   WI     382
# 2     Marizanne Kapp   SA     349
# 3       Ellyse Perry  AUS     329
# 4        Amelia Kerr   NZ     328
# 5      Deepti Sharma  IND     312
# 6      Jess Jonassen  AUS     241
# 7      Sophie Devine   NZ     233
# 8           Nida Dar  PAK     232
# 9  Sophie Ecclestone  ENG     200

# %% [markdown]
# # 5) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :
#
# i) Headline
#
# ii) Time
#
# iii) News Link

# %%
# Send url request and download page source code
News_soup=BeautifulSoup(requests.get("https://www.cnbc.com/world/?region=world").content,"html.parser")
Headline=[i.text for i in News_soup.find_all(class_="LatestNews-headline") ] # Scrap Headlines
Time=[i.text for i in News_soup.find_all("span",class_="LatestNews-wrapper") ] # Scrap Time
# Scrap news Links
for links in News_soup.find_all("a",class_="LatestNews-headline"):
    links=links.get('href')
# Create data frame
news1=pd.DataFrame({'Headlines':Headline,'Time':Time,"Link":links})
news1
# Out:
#                                             Headlines         Time  \
# 0   4 reasons why consumers are confusing — and wh...    7 Min Ago
# 1   Hawaii wildfires leave at least 96 dead, more ...   24 Min Ago
# 2   Michael Burry of ‘The Big Short’ fame reveals ...   25 Min Ago
# 3     DeSantis urges Bob Iger to drop Disney lawsuit    34 Min Ago
# 4   Why you should plan for volatility, even with ...   36 Min Ago
# 5   Judge in Trump New York porn star hush money c...   48 Min Ago
# 6   We're booking profits in this off-price retail...   50 Min Ago
# 7   Stocks making the biggest moves midday: AMC, U...   56 Min Ago
# 8   Tiger Cub hedge fund Coatue trims Nvidia expos...   57 Min Ago
# 9   Jim Cramer talks about his 'favorite stock,' t...   58 Min Ago
# 10  This woman turned 114 last week: Doctors say s...   59 Min Ago
# 11  Why we're still reading 'The Body Keeps the Sc...   1 Hour Ago
# 12  UBS says this stock is the 'best story' among ...   1 Hour Ago
# 13  Mark Zuckerberg calls off Elon Musk cage match...   1 Hour Ago
# 14  Argentina jacks up interest rates after shock ...   1 Hour Ago
# 15  'Accept the fact that stocks go down,' Jim Cra...   1 Hour Ago
# 16  Hawaiian Electric shares drop 30% on concern a...   1 Hour Ago
# 17  Jim Cramer calls Monday.com a 'junior' Salesfo...  2 Hours Ago
# 18  Kraft Heinz picks new CEO as sales slump in th...  2 Hours Ago
# 19  Starboard Value’s Jeffrey Smith, who's bullish...  2 Hours Ago
# 20  Georgia DA set to present Trump election inter...  2 Hours Ago
# 21  Goldman loves this 'cash flow compounder' and ...  2 Hours Ago
# 22  Why you should use ChatGPT on your resume, say...  2 Hours Ago
# 23  Nikola shares fall after EV maker recalls all ...  2 Hours Ago
# 24    Saudi soccer league lures Brazilian star Neymar  3 Hours Ago
# 25  Buy this retailer before it tops earnings and ...  3 Hours Ago
# 26  Baupost builds new stake in Amazon, adds a dis...  3 Hours Ago
# 27  Here are the 13 stocks Jim Cramer is watching,...  3 Hours Ago
# 28  China wants Russia to be in a 'Goldilocks' sta...  3 Hours Ago
# 29  Trump targets judge in federal election case, ...  3 Hours Ago
#
#                                                  Link
# 0   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 1   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 2   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 3   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 4   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 5   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 6   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 7   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 8   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 9   https://www.cnbc.com/2023/08/14/trump-accuses-...
# 10  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 11  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 12  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 13  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 14  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 15  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 16  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 17  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 18  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 19  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 20  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 21  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 22  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 23  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 24  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 25  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 26  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 27  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 28  https://www.cnbc.com/2023/08/14/trump-accuses-...
# 29  https://www.cnbc.com/2023/08/14/trump-accuses-...

# %% [markdown]
# # 6) Write a python program to scrape the details of most downloaded articles from AI in last 90 days.
# https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape below mentioned details :
#
# i) Paper Title
#
# ii) Authors
#
# iii) Published Date
#
# iv) Paper URL

# %%
#send get request to the webpage server to get the source code of the page and download the page content
AI_soup=BeautifulSoup(requests.get("https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles").content,"html.parser")
paper_title=[i.text for i in AI_soup.find_all("h2",class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR") ] # scrap title

author=[i.text for i in AI_soup.find_all("span",class_="sc-1w3fpd7-0 pgLAT") ] #scrap author

date=[i.text for i in AI_soup.find_all("span",class_="sc-1thf9ly-2 bKddwo") ] # date

news = AI_soup.find_all('li', {'class','sc-9zxyh7-1 sc-9zxyh7-2 exAXfr jQmQZp'})
lnk = [each.a.get('href') for each in news] # scrap news link

ai_articles=pd.DataFrame({"Paper Title":paper_title,"Authors":author,"Published Date":date,"Paper URL":lnk}) # DataFrame Created
ai_articles
# Out:
# Empty DataFrame
# Columns: [Paper Title, Authors, Published Date, Paper URL]
# Index: []

# %% [markdown]
# # 7) Write a python program to scrape mentioned details from dineout.co.in :
#
# i) Restaurant name
#
# ii) Cuisine
#
# iii) Location
#
# iv) Ratings
#
# v) Image URL

# %%
#send get request to the webpage server to get the source code of the page and download the page content
soup=BeautifulSoup(requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special').content,'html.parser')
name=[i.text.split(',')[0] for i in soup.find_all('div',class_='restnt-info cursor')] # Scrap Restaurant name
location=[i.text for i in soup.find_all('div',class_='restnt-loc ellipsis')] # Scrap location
image=[i['data-src'] for i in soup.find_all("img", class_="no-img")] # scrap url of image
cuisine=[i.text.split('|')[1] for i in soup.find_all('span',class_="double-line-ellipsis")] # scrap cuisine
rating=[i.text for i in soup.find_all('div',class_='restnt-rating rating-4')] # scrap rating
df=pd.DataFrame({'Restaurant Name':name,'Cuisine':cuisine,'Location':location,"Rating":rating,"Image_url": image})
df
# Out:
#                                      Restaurant Name  \
# 0                     Castle BarbequeConnaught Place
# 1      Cafe KnoshThe Leela Ambience Convention Hotel
# 2                      Castle's BarbequePacific Mall
# 3               The Barbeque CompanyGardens Galleria
# 4                       India GrillHilton Garden Inn
# 5               Delhi BarbequeTaurus Sarovar Portico
# 6  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 7               The Barbeque TimesM2K Corporate Park
# 8            Indian Grill RoomSuncity Business Tower
#
#                                              Cuisine  \
# 0                              Chinese, North Indian
# 1                               Italian, Continental
# 2                              Chinese, North Indian
# 3                              North Indian, Chinese
# 4                              North Indian, Italian
# 5                                       North Indian
# 6                                       North Indian
# 7   North Indian, Continental, Chinese, South Indian
# 8                              North Indian, Mughlai
#
#                                             Location Rating  \
# 0                     Connaught Place, Central Delhi      4
# 1  The Leela Ambience Convention Hotel,Shahdara, ...    4.3
# 2             Pacific Mall,Tagore Garden, West Delhi    3.9
# 3                 Gardens Galleria,Sector 38A, Noida    3.9
# 4               Hilton Garden Inn,Saket, South Delhi    3.9
# 5     Taurus Sarovar Portico,Mahipalpur, South Delhi    3.7
# 6  Indirapuram Habitat Centre,Indirapuram, Ghaziabad    3.8
# 7              M2K Corporate Park,Sector 51, Gurgaon    4.1
# 8   Suncity Business Tower,Golf Course Road, Gurgaon    4.3
#
#                                            Image_url
# 0  https://im1.dineout.co.in/images/uploads/resta...
# 1  https://im1.dineout.co.in/images/uploads/resta...
# 2  https://im1.dineout.co.in/images/uploads/resta...
# 3  https://im1.dineout.co.in/images/uploads/resta...
# 4  https://im1.dineout.co.in/images/uploads/resta...
# 5  https://im1.dineout.co.in/images/uploads/resta...
# 6  https://im1.dineout.co.in/images/uploads/resta...
# 7  https://im1.dineout.co.in/images/uploads/resta...
# 8  https://im1.dineout.co.in/images/uploads/resta...
